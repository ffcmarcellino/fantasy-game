# %%
import pandas as pd
import requests as rq
import json

# %%
api = rq.get("https://api.cartolafc.globo.com/atletas/mercado")

# %%
market = json.loads(api.text)

# %%
market.keys()
# Out:
# dict_keys(['atletas', 'clubes', 'posicoes', 'status'])

# %%
roundN = pd.DataFrame(market["atletas"])

# %%
roundN.head(10)
# Out:
#           apelido  atleta_id  clube_id  \
# 0       Kannemann      87342       284
# 1          Cássio      42234       264
# 2      Martín Rea     103093       282
# 3  Bruno Henrique      90285       262
# 4            Renê      78445       262
# 5   Pedro Geromel      80853       284
# 6         Gabriel      83257       262
# 7  Carlos Sánchez      81677       277
# 8          Fagner      42500       264
# 9           Cueva      82411       277
#
#                                                 foto  jogos_num  media_num  \
# 0  https://s.glbimg.com/es/sde/f/2018/05/21/7a4b8...          3       3.70
# 1  https://s.glbimg.com/es/sde/f/2019/05/18/a1c00...          5       4.78
# 2  https://s.glbimg.com/es/sde/f/2018/08/15/112cf...          0       0.00
# 3  https://s.glbimg.com/es/sde/f/2019/04/26/195ab...          5       6.06
# 4  https://s.glbimg.com/es/sde/f/2019/04/26/f7f5e...          3       1.13
# 5  https://s.glbimg.com/es/sde/f/2018/05/21/afc76...          4       5.80
# 6  https://s.glbimg.com/es/sde/f/2019/04/26/dd351...          3       4.57
# 7  https://s.glbimg.com/es/sde/f/2019/03/28/c138b...          4       5.28
# 8  https://s.glbimg.com/es/sde/f/2019/03/18/d5cd8...          4       8.42
# 9  https://s.glbimg.com/es/sde/f/2019/03/29/52188...          3       1.37
#
#                             nome  pontos_num  posicao_id  preco_num  \
# 0               Walter Kannemann         0.0           3      14.70
# 1                   Cássio Ramos        15.0           1       8.61
# 2            Martín Rea Zuccotti         0.0           3       4.00
# 3           Bruno Henrique Pinto        12.1           5      19.82
# 4         Renê Rodrigues Martins         3.9           2       5.90
# 5            Pedro Tonon Geromel         6.0           3      12.48
# 6        Gabriel Barbosa Almeida         0.8           5      14.38
# 7   Carlos Andrés Sánchez Arcosa         6.5           4      12.31
# 8          Fagner Conserva Lemos        10.2           2      12.78
# 9  Christian Alberto Cueva Bravo         3.1           4       7.16
#
#    rodada_id                                              scout  \
# 0          5  {'CA': 3, 'FC': 9, 'FS': 4, 'G': 1, 'PE': 3, '...
# 1          5  {'CA': 2, 'DD': 7, 'FS': 1, 'GS': 4, 'PE': 2, ...
# 2          5                                                 {}
# 3          5  {'CA': 1, 'FC': 4, 'FD': 5, 'FF': 6, 'FS': 3, ...
# 4          5  {'CA': 1, 'FC': 2, 'FD': 1, 'FS': 2, 'PE': 6, ...
# 5          5  {'CA': 1, 'FC': 1, 'FF': 2, 'FS': 4, 'PE': 8, ...
# 6          5  {'CA': 1, 'FC': 1, 'FD': 4, 'FF': 2, 'FS': 5, ...
# 7          5  {'FC': 6, 'FD': 4, 'FF': 4, 'FS': 6, 'FT': 2, ...
# 8          5  {'A': 1, 'CA': 1, 'FC': 1, 'FD': 1, 'FS': 9, '...
# 9          5               {'FC': 2, 'FS': 3, 'PE': 8, 'RB': 4}
#
#              slug  status_id  variacao_num
# 0       kannemann          2          0.00
# 1          cassio          7          2.83
# 2      martin-rea          6          0.00
# 3  bruno-henrique          7          2.27
# 4            rene          7         -0.12
# 5   pedro-geromel          7         -0.02
# 6         gabriel          7         -2.53
# 7  carlos-sanchez          7          0.49
# 8          fagner          7          1.51
# 9           cueva          6         -0.07

# %%
roundN.to_csv("round5.csv")
